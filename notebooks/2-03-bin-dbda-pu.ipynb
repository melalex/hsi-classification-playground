# %% [markdown]
# # Indiana Pines

# %% [markdown]
# 1. Import dependencies

# %%
import random
import torch
import multiprocessing
import numpy as np

import torch.utils.data as data

from lightning import Trainer

from src.util.torch import resolve_torch_device
from src.util.hsi import (
    extract_patches,
    reduce_hsi_dim,
    preprocess_hsi,
    read_fixed_labels_mask,
    pu_bin_train_test_split_by_mask,
    PreProcessType,
    DimReductionType,
)
from src.data.indian_pines import load_indian_pines
from src.model.hsic import HyperSpectralImageClassifier
from src.visualization.plot import (
    plot_segmentation_comparison,
    plot_epoch_generic,
    plot_masked_segmentation_comparison,
    plot_epoch_generic_comparison,
)

from src.data.dataset_decorator import UnlabeledDatasetDecorator
from src.util.reporting import (
    create_model_name,
    report_run,
    read_report_to_show,
    lightning_metrics,
)
from src.util.list_ext import smooth_moving_average
from src.model.dbda import DBDA
from src.util.dict_ext import arrange_and_repeat, unique_counts
from src.definitions import RAW_DATA_FOLDER
from src.util.loss import PuLoss
from src.trainer.base_trainer import LrSchedulerProvider

# %% [markdown]
# 2. Prepare env

# %%
target_class = 11
data_point_count = 245

# %%
learning_rate = 1e-3
weight_decay = 0
num_epochs = 100

# %%
batch_size = 24
patch_size = 9
target_dim = 75

examples_per_class = {}

pre_process_type = PreProcessType.STANDARTIZATION
dim_reduction_type = DimReductionType.PCA

# %%
random_seed = 42

random.seed(random_seed)
torch.manual_seed(random_seed)
np.random.seed(random_seed)

device = resolve_torch_device()

# %%
torch.cuda.empty_cache()

# %%
torch.set_float32_matmul_precision("medium")

# %%
f"Device is {device}"
# Out:
# 'Device is cuda'

# %% [markdown]
# 3. Load dataset

# %%
image, labels = load_indian_pines()

image_h, image_w, image_c = image.shape

# %%
_, image = preprocess_hsi(image, pre_process_type)

# %%
_, target_dim, image = reduce_hsi_dim(
    image, target_dim, dim_reduction_type, random_seed
)

# %%
x, y = extract_patches(image, labels, patch_size=patch_size)

# %%
num_classes = len(np.unique(y))

f"Number of classes {num_classes}"
# Out:
# 'Number of classes 17'

# %%
examples_per_class = arrange_and_repeat(num_classes, 20)

# %%
mask = read_fixed_labels_mask(
    f"indian-pines-train-test-split-{target_class}-{data_point_count}.npy",
    folder=RAW_DATA_FOLDER / "mask" / "train-test-split",
)

x_train, y_train, _, _ = pu_bin_train_test_split_by_mask(target_class, x, y, mask)

# p_indices = np.where(y_train == 1)[0]
# u_indices = np.where(y_train == -1)[0]

# p_count = len(p_indices)

# selected_u_indecies = np.random.choice(u_indices, size=p_count, replace=False)

# balanced_indices = np.concatenate([p_indices, selected_u_indecies])

# np.random.shuffle(balanced_indices)

# x_train = x_train[balanced_indices]
# y_train = y_train[balanced_indices]

_ = plot_masked_segmentation_comparison(y.reshape(image_h, image_w), mask)

# %%
y_train_unique = unique_counts(y_train)

y_train_unique
# Out:
# {-1: 20780, 1: 245}

# %%
y_target = y == target_class

# %%
x_tensor = torch.tensor(x, dtype=torch.float32).permute(0, 3, 1, 2) 
y_tensor = torch.tensor(y_target, dtype=torch.long)
x_train_tensor = torch.tensor(x_train, dtype=torch.float32).permute(0, 3, 1, 2)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

# %%
x_tensor.shape
# Out:
# torch.Size([21025, 75, 9, 9])

# %%
cpu_count = multiprocessing.cpu_count()

f"Setting num_workers to {cpu_count}"
# Out:
# 'Setting num_workers to 24'

# %%
train_dataset = data.TensorDataset(x_train_tensor, y_train_tensor)
full_dataset = data.TensorDataset(x_tensor, y_tensor)

train_loader = data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=cpu_count,
    persistent_workers=True,
)
full_loader = data.DataLoader(
    full_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=cpu_count,
    persistent_workers=True,
)
predict_loader = data.DataLoader(
    UnlabeledDatasetDecorator(full_dataset),
    batch_size=batch_size,
    num_workers=cpu_count,
    persistent_workers=True,
)

# %% [markdown]
# 4. Train model

# %%
positive_count = (y == target_class).sum()
all_count = len(y)
positive_prob = torch.tensor(positive_count / all_count, dtype=torch.float32)

# %%
print(f"{target_class} count: {positive_count}")
print(f"Overall count: {all_count}")
print(f"Class prob: {positive_prob}")
# Out:
# 11 count: 2455
# Overall count: 21025
# Class prob: 0.11676575243473053

# %%
def extract_prediction(y_hat):
    return (torch.sigmoid(y_hat) > 0.5).to(dtype=torch.int)

# %%
backbone_model = DBDA(band=target_dim, classes=1, flatten_out=True)

# %%
loss = PuLoss(
    prior=positive_prob,
    nnpu=True,
    loss_fn=lambda x: torch.nn.functional.softplus(-x),
)

# %%
model = HyperSpectralImageClassifier(
    backbone_model,
    2,
    lr=learning_rate,
    weight_decay=weight_decay,
    loss_fun=loss,
    pred_extractor=extract_prediction,
    scheduler=LrSchedulerProvider(
        t_initial=num_epochs,
        lr_min=learning_rate * 0.01,
        warmup_t=int(np.ceil(0.1 * num_epochs)),
        warmup_lr_init=learning_rate * 0.01,
    ),
)

trainer = Trainer(accelerator="auto", max_epochs=num_epochs)
# Out:
# You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/melal/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %%
trainer.fit(
    model,
    train_loader,
    full_loader,
)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 trainer.fit(
#       2     model,
#       3     train_loader,
#       4     full_loader,
#       5 )
#
# File ~/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py:561, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     559 self.training = True
#     560 self.should_stop = False
# --> 561 call._call_and_handle_interrupt(
#     562     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     563 )
#
# File ~/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:48, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46     if trainer.strategy.launcher is not None:
#      47         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 48     return trainer_fn(*args, **kwargs)
#      50 except _TunerExitException:
#      51     _call_teardown_hook(trainer)
#
# File ~/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py:599, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     592     download_model_from_registry(ckpt_path, self)
#     593 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     594     self.state.fn,
#     595     ckpt_path,
#     596     model_provided=True,
#     597     model_connected=self.lightning_module is not None,
#     598 )
# --> 599 self._run(model, ckpt_path=ckpt_path)
#     601 assert self.state.stopped
#     602 self.training = False
#
# File ~/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py:988, in Trainer._run(self, model, ckpt_path)
#     985 self._logger_connector.reset_metrics()
#     987 # strategy will configure model and move it to the device
# --> 988 self.strategy.setup(self)
#     990 # hook
#     991 if self.state.fn == TrainerFn.FITTING:
#
# File ~/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py:159, in Strategy.setup(self, trainer)
#     156 self.model = self._setup_model(self.model)
#     158 if trainer.state.fn == TrainerFn.FITTING:
# --> 159     self.setup_optimizers(trainer)
#     160 self.setup_precision_plugin()
#     161 if trainer.state.fn == TrainerFn.FITTING:
#
# File ~/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py:139, in Strategy.setup_optimizers(self, trainer)
#     132 """Creates optimizers and schedulers.
#     133
#     134 Args:
#     135     trainer: the Trainer, these optimizers should be connected to
#     136
#     137 """
#     138 assert self.lightning_module is not None
# --> 139 self.optimizers, self.lr_scheduler_configs = _init_optimizers_and_lr_schedulers(self.lightning_module)
#
# File ~/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/core/optimizer.py:180, in _init_optimizers_and_lr_schedulers(model)
#     177 """Calls `LightningModule.configure_optimizers` and parses and validates the output."""
#     178 from lightning.pytorch.trainer import call
# --> 180 optim_conf = call._call_lightning_module_hook(model.trainer, "configure_optimizers", pl_module=model)
#     182 if optim_conf is None:
#     183     rank_zero_warn(
#     184         "`LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer",
#     185     )
#
# File ~/Workspace/hsi-classification-playground/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:176, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     173 pl_module._current_fx_name = hook_name
#     175 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 176     output = fn(*args, **kwargs)
#     178 # restore current_fx when nested context
#     179 pl_module._current_fx_name = prev_fx_name
#
# File ~/Workspace/hsi-classification-playground/src/model/hsic.py:140, in HyperSpectralImageClassifier.configure_optimizers(self)
#     136 optimizer = optim.Adam(
#     137     self.parameters(), lr=self.lr, weight_decay=self.weight_decay
#     138 )
#     139 if self.scheduler:
# --> 140     scheduler = self.scheduler(optimizer)
#     141     return {
#     142         "optimizer": optimizer,
#     143         "lr_scheduler": {
#    (...)    148         },
#     149     }
#     150 else:
#
# TypeError: 'LrSchedulerProvider' object is not callable

# %%
smothed_train = smooth_moving_average([it.loss.cpu() for it in model.train_metrics], 1)
smothed_eval = smooth_moving_average([it.loss.cpu() for it in model.val_metrics], 1)

plot_epoch_generic_comparison(smothed_train, smothed_eval)

# %%
smothed_train = smooth_moving_average([it.loss.cpu() for it in model.train_metrics], 1)

plot_epoch_generic(smothed_train, desc="Loss")

# %%
smooth_f1 = smooth_moving_average([it.f1.cpu() for it in model.val_metrics], 1)

plot_epoch_generic(smooth_f1, desc="F1")

# %%
validation_result = trainer.validate(model, full_loader)

validation_result

# %% [markdown]
# 2. Display prediction

# %%
y_pred = trainer.predict(model, predict_loader)

# %%
y_pred = torch.cat(y_pred, dim=0)
y_pred = extract_prediction(y_pred)
y_pred = y_pred.reshape(image_h, image_w)

# %%
plot_segmentation_comparison(y_target.reshape(image_h, image_w), y_pred.numpy(), num_classes)

# %% [markdown]
# 6. Write report

# %%
model_name = create_model_name("indian_pines_", {target_class: y_train_unique[1]})
model_category = "dbda"

# %%
run_params = {
    "num_epochs": num_epochs,
    "batch_size": batch_size,
    "patch_size": patch_size,
    "target_dim": target_dim,
    "pre_process_type": str(pre_process_type),
    "dim_reduction_type": str(dim_reduction_type),
}

report_run(
    model_name=model_name,
    model_category=model_category,
    run_desc="More epochs",
    run_params=run_params | model.get_params(),
    run_metrics=lightning_metrics(validation_result),
)

# %%
read_report_to_show(model_name, sort_by_metric="f1")

# %%
read_report_to_show(model_name, sort_by_metric="f1", model_category=model_category)
