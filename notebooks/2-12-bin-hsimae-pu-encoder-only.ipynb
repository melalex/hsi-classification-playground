# %% [markdown]
# # Indiana Pines

# %% [markdown]
# 1. Import dependencies

# %%
import random
import torch
import multiprocessing
import numpy as np

import torch.utils.data as data

from src.util.torch import resolve_torch_device
from src.util.hsi import (
    extract_patches,
    reduce_hsi_dim,
    preprocess_hsi,
    read_fixed_labels_mask,
    pu_bin_train_test_split_by_mask,
    PreProcessType,
    DimReductionType,
)
from src.data.indian_pines import load_indian_pines
from src.visualization.plot import (
    plot_segmentation_comparison,
    plot_epoch_generic,
    plot_masked_segmentation_comparison,
    plot_epoch_generic_comparison,
)

from src.data.dataset_decorator import UnlabeledDatasetDecorator
from src.util.reporting import (
    create_model_name,
    report_run,
    read_report_to_show,
    classification_trainer,
)
from src.util.list_ext import smooth_moving_average
from src.util.dict_ext import unique_counts
from src.definitions import RAW_DATA_FOLDER
from src.trainer.base_trainer import AdamOptimizedModule
from src.util.loss import (
    PuLoss,
    logistic_loss,
)
from src.trainer.model_storage import SimpleFileBackedModelStorage
from src.trainer.hsimae_trainer import DualHsiMaeTrainer
from src.data.dataset_decorator import RandomFlipDatasetDecorator
from src.trainer.base_trainer import LrSchedulerProvider
from src.model.hsimae import DualViT
from src.data.dataset_decorator import HsiMaeAdapterDatasetDecorator
from src.trainer.classification_trainer import ClassificationTrainer

# %% [markdown]
# 2. Prepare env

# %%
run_desc = "Default run"

# %%
target_class = 11
data_point_count = 171

# %%
learning_rate = 1e-3
weight_decay = 0
num_epochs = 30

# %%
encoder_dim = 256
encoder_depth = 12
decoder_dim = 64
decoder_depth = 8
s_depth = 9
mask_ratio = 0.75
b_patch_size = 5
rec_loss_weight = 1
pu_loss_gamma = 1.0

# %%
batch_size = 256
patch_size = 9
target_dim = 75

pre_process_type = PreProcessType.STANDARTIZATION
dim_reduction_type = DimReductionType.PCA

# %%
random_seed = 42

random.seed(random_seed)
torch.manual_seed(random_seed)
np.random.seed(random_seed)

device = resolve_torch_device()

# %%
torch.cuda.empty_cache()

# %%
torch.set_float32_matmul_precision("medium")

# %%
f"Device is {device}"
# Out:
# 'Device is cuda'

# %% [markdown]
# 3. Load dataset

# %%
image, labels = load_indian_pines()

image_h, image_w, image_c = image.shape

# %%
_, image = preprocess_hsi(image, pre_process_type)

# %%
_, target_dim, image = reduce_hsi_dim(
    image, target_dim, dim_reduction_type, random_seed
)

# %%
x, y = extract_patches(image, labels, patch_size=patch_size)

# %%
num_classes = len(np.unique(y))

f"Number of classes {num_classes}"
# Out:
# 'Number of classes 17'

# %%
mask = read_fixed_labels_mask(
    f"indian-pines-train-test-split-{target_class}-{data_point_count}.npy",
    folder=RAW_DATA_FOLDER / "mask" / "train-test-split",
)

x_train, y_train, _, _ = pu_bin_train_test_split_by_mask(target_class, x, y, mask)


_ = plot_masked_segmentation_comparison(y.reshape(image_h, image_w), mask)

# %%
y_train_unique = unique_counts(y_train)
labeled_datapoints_count = y_train_unique[1]

y_train_unique
# Out:
# {-1: 20854, 1: 171}

# %%
y_target = y == target_class

# %%
x_tensor = torch.tensor(x, dtype=torch.float32).permute(0, 3, 1, 2) 
y_tensor = torch.tensor(y_target, dtype=torch.long)
x_train_tensor = torch.tensor(x_train, dtype=torch.float32).permute(0, 3, 1, 2)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

# %%
x_tensor.shape
# Out:
# torch.Size([21025, 75, 9, 9])

# %%
cpu_count = multiprocessing.cpu_count()

f"Setting num_workers to {cpu_count}"
# Out:
# 'Setting num_workers to 24'

# %%
train_dataset = data.TensorDataset(x_train_tensor, y_train_tensor)
full_dataset = HsiMaeAdapterDatasetDecorator(data.TensorDataset(x_tensor, y_tensor))

train_loader = data.DataLoader(
    HsiMaeAdapterDatasetDecorator(RandomFlipDatasetDecorator(train_dataset)),
    batch_size=batch_size,
    shuffle=True,
    num_workers=cpu_count,
    persistent_workers=True,
)
full_loader = data.DataLoader(
    full_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=cpu_count,
    persistent_workers=True,
)
predict_loader = data.DataLoader(
    UnlabeledDatasetDecorator(full_dataset),
    batch_size=batch_size,
    num_workers=cpu_count,
    persistent_workers=True,
)

# %% [markdown]
# 4. Train model

# %%
positive_count = (y == target_class).sum()
all_count = len(y)
positive_prob = torch.tensor(positive_count / all_count, dtype=torch.float32)

# %%
print(f"{target_class} count: {positive_count}")
print(f"Overall count: {all_count}")
print(f"Class prob: {positive_prob}")
# Out:
# 11 count: 2455
# Overall count: 21025
# Class prob: 0.11676575243473053

# %%
def extract_prediction(y_hat):
    return (torch.sigmoid(y_hat) > 0.5).to(dtype=torch.int)

# %%
pu_loss = PuLoss(
    prior=positive_prob, nnpu=True, loss_fn=logistic_loss, gamma=pu_loss_gamma
)

# %%
backbone = DualViT(
    img_size=patch_size,
    num_class=1,
    patch_size=3,
    in_chans=1,
    bands=target_dim,
    b_patch_size=b_patch_size,
    embed_dim=encoder_dim,
    depth=encoder_depth,
    num_heads=encoder_dim // 16,
    s_depth=s_depth,
    decoder_embed_dim=decoder_dim,
    decoder_depth=decoder_depth,
    decoder_num_heads=decoder_dim // 8,
    norm_pix_loss=True,
    trunc_init=True,
    skip_decoder=True
)
# Out:
# img_size (9, 9) patch_size (3, 3) bands 75 b_patch_size 5
# model initialized

# %%
model = AdamOptimizedModule(
    net=backbone,
    lr=learning_rate,
    weight_decay=weight_decay,
    scheduler=LrSchedulerProvider(
        t_initial=num_epochs,
        lr_min=1e-6,
        warmup_t=int(np.ceil(0.1 * num_epochs)),
        warmup_lr_init=learning_rate * 0.01,
    ),
).to(device)

# %%
trainer = ClassificationTrainer(
    num_epochs=num_epochs,
    criterion=pu_loss,
    num_classes=2,
    device=device,
    extract_prediction=extract_prediction,
    =SimpleFileBackedModelStorage(
        "eval_kappa",
        f"indian_pines_bin_hsimae_pu_{target_class}_{labeled_datapoints_count}",
    ),
)

# %%
feedback, best_model = trainer.fit(
    model,
    train_loader,
    full_loader,
)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
smothed_train = smooth_moving_average(
    [it.train["train_loss"] for it in feedback.history], 1
)
smothed_eval = smooth_moving_average(
    [it.eval["eval_loss"] for it in feedback.history], 1
)

plot_epoch_generic_comparison(smothed_train, smothed_eval)

# %%
smooth_f1 = smooth_moving_average([it.eval["eval_f1"] for it in feedback.history], 1)

plot_epoch_generic(smooth_f1, desc="F1")

# %%
smooth_f1 = smooth_moving_average([it.eval["eval_kappa"] for it in feedback.history], 1)

plot_epoch_generic(smooth_f1, desc="Kappa")

# %%
validation_result = trainer.validate(best_model, full_loader)

validation_result
# Out:
# {'eval_f1': 0.9634658098220825,
#  'eval_accuracy_overall': 0.899703860282898,
#  'eval_accuracy_avg': 0.9639476537704468,
#  'eval_kappa': 0.8205822110176086,
#  'eval_loss': 0.12495196368320878}

# %% [markdown]
# 2. Display prediction

# %%
_, y_pred = trainer.predict(best_model, predict_loader)

# %%
y_pred = torch.cat(y_pred, dim=0)
y_pred = extract_prediction(y_pred)
y_pred = y_pred.reshape(image_h, image_w)
y_pred = y_pred.cpu()

# %%
plot_segmentation_comparison(y_target.reshape(image_h, image_w), y_pred.numpy(), num_classes)

# %% [markdown]
# 6. Write report

# %%
model_name = create_model_name(
    "indian_pines_", {target_class: labeled_datapoints_count}
)
model_category = "hsimae-pu-encoder-only"

# %%
run_params = {
    "batch_size": batch_size,
    "patch_size": patch_size,
    "target_dim": target_dim,
    "pre_process_type": str(pre_process_type),
    "dim_reduction_type": str(dim_reduction_type),
    "mask_ratio": mask_ratio,
    "pre_process_type": str(pre_process_type),
    "dim_reduction_type": str(dim_reduction_type),
    "pu_loss_gamma": pu_loss_gamma,
}

all_params = run_params | model.get_params() | trainer.get_params()

# %%
report_run(
    model_name=model_name,
    model_category=model_category,
    run_desc=run_desc,
    run_params=all_params,
    run_metrics=classification_trainer(validation_result),
)
# Out:
# PosixPath('/home/melal/Workspace/hsi-classification-playground/reports/runs/indian_pines__11-171.csv')

# %%
read_report_to_show(model_name, sort_by_metric="kappa")
# Out:
#                            timestamp          model_category  \
# 20  2025-08-23T17:02:16.520781+00:00               hsimae-pu
# 21  2025-08-23T18:58:25.579932+00:00  hsimae-pu-encoder-only
# 19  2025-08-21T11:00:53.166963+00:00             mae-pu-dbda
# 12  2025-08-20T16:07:35.321103+00:00             mae-pu-dbda
# 13  2025-08-20T16:33:10.248419+00:00             mae-pu-dbda
# 17  2025-08-20T19:37:43.238916+00:00             mae-pu-dbda
# 14  2025-08-20T17:04:17.574232+00:00             mae-pu-dbda
# 15  2025-08-20T18:06:52.793759+00:00             mae-pu-dbda
# 18  2025-08-20T20:03:32.052939+00:00             mae-pu-dbda
# 5   2025-08-20T09:28:27.780000+00:00             mae-pu-dbda
# 9   2025-08-20T14:00:37.217246+00:00             mae-pu-dbda
# 4   2025-08-19T20:21:18.981875+00:00                    dbda
# 11  2025-08-20T15:03:12.246399+00:00             mae-pu-dbda
# 7   2025-08-20T12:26:04.582071+00:00             mae-pu-dbda
# 10  2025-08-20T14:35:44.837097+00:00             mae-pu-dbda
# 16  2025-08-20T18:41:54.962676+00:00             mae-pu-dbda
# 6   2025-08-20T12:07:45.895623+00:00             mae-pu-dbda
# 8   2025-08-20T12:41:31.215230+00:00             mae-pu-dbda
# 3   2025-08-08T15:17:34.155442+00:00                    dbda
# 2   2025-08-05T19:51:31.128416+00:00                    dbda
# 0   2025-08-05T18:41:51.415053+00:00                    dbda
# 1   2025-08-05T19:05:48.742036+00:00                    dbda
#
#                                              run_desc  \
# 20                                        Default run
# 21                                        Default run
# 19  Patch flips + 512 batch size + more epochs + s...
# 12                            Default run more epochs
# 13                          Patch flips + more epochs
# 17         Patch flips + more epochs + 512 batch size
# 14      Patch flips + more epochs + bigger batch size
# 15      Patch flips + more epochs + bigger batch size
# 18    Patch flips + 512 batch size + turn off decoder
# 5                                         Default run
# 9                                         Default run
# 4                                         Default run
# 11                            Default run more epochs
# 7                                         Default run
# 10                                        Default run
# 16        Patch flips + more epochs + less batch size
# 6                            Change cls head training
# 8                                         Default run
# 3                                              New PU
# 2                                            BCE loss
# 0                                      PU default run
# 1                                      PU default run
#
#                                                params          loss        f1  \
# 20  {"batch_size": 256, "patch_size": 9, "target_d...  1.274573e-01  0.966029
# 21  {"batch_size": 256, "patch_size": 3, "target_d...  1.249520e-01  0.963466
# 19  {"num_epochs": 240, "batch_size": 512, "patch_...  1.290940e-01  0.959706
# 12  {"num_epochs": 60, "batch_size": 64, "patch_si...  4.407637e-02  0.957685
# 13  {"num_epochs": 60, "batch_size": 64, "patch_si...  4.250109e-02  0.954242
# 17  {"num_epochs": 60, "batch_size": 512, "patch_s...  5.354339e-02  0.940480
# 14  {"num_epochs": 60, "batch_size": 126, "patch_s...  5.374009e-02  0.943948
# 15  {"num_epochs": 60, "batch_size": 256, "patch_s...  7.577282e-02  0.934311
# 18  {"num_epochs": 60, "batch_size": 512, "patch_s...  6.304820e-02  0.932953
# 5   {"num_epochs": 30, "batch_size": 64, "patch_si...  6.739401e-02  0.931125
# 9   {"num_epochs": 30, "batch_size": 64, "patch_si...  3.268514e-02  0.920969
# 4   {"prediction_threshold": 0.5, "target_dim": 75...  1.064591e-01  0.906631
# 11  {"num_epochs": 60, "batch_size": 64, "patch_si...  4.703137e-02  0.876954
# 7   {"num_epochs": 30, "batch_size": 64, "patch_si...  3.342330e-02  0.867119
# 10  {"num_epochs": 30, "batch_size": 64, "patch_si...  3.427086e-02  0.862055
# 16  {"num_epochs": 60, "batch_size": 64, "patch_si...  3.590604e-02  0.858247
# 6   {"num_epochs": 30, "batch_size": 64, "patch_si...  3.540006e-02  0.855657
# 8   {"num_epochs": 30, "batch_size": 64, "patch_si...  3.474835e-02  0.846302
# 3   {"num_epochs": 10, "learning_rate": 0.001, "t_...  1.009237e-01  0.829513
# 2   {"num_epochs": 10, "learning_rate": 0.001, "t_...  6.583450e+01  0.024417
# 0   {"num_epochs": 30, "learning_rate": 0.001, "t_...  8.715523e-15  0.828471
# 1   {"num_epochs": 10, "learning_rate": 0.001, "t_...  7.502179e-13  0.828471
#
#           OA        AA     kappa
# 20  0.907290  0.966421  0.833434
# 21  0.899704  0.963948  0.820582
# 19  0.938864  0.958193  0.812397
# 12  0.908076  0.957194  0.797269
# 13  0.869530  0.955291  0.773224
# 17  0.890970  0.938216  0.723029
# 14  0.840857  0.945541  0.720825
# 15  0.936774  0.928276  0.715273
# 18  0.922123  0.927372  0.705680
# 5   0.882084  0.927515  0.684991
# 9   0.725321  0.931272  0.574911
# 4   0.795843  0.904114  0.560013
# 11  0.626903  0.894792  0.332262
# 7   0.576336  0.900690  0.240752
# 10  0.564969  0.898407  0.208743
# 16  0.557000  0.896504  0.185134
# 6   0.551800  0.895125  0.169267
# 8   0.532967  0.890892  0.110830
# 3   0.501833  0.883662  0.006458
# 2   0.500000  0.116766  0.000000
# 0   0.500000  0.883234  0.000000
# 1   0.500000  0.883234  0.000000

# %%
read_report_to_show(model_name, sort_by_metric="kappa", model_category=model_category)
# Out:
#                            timestamp     run_desc  \
# 21  2025-08-23T18:58:25.579932+00:00  Default run
#
#                                                params      loss        f1  \
# 21  {"batch_size": 256, "patch_size": 3, "target_d...  0.124952  0.963466
#
#           OA        AA     kappa
# 21  0.899704  0.963948  0.820582
